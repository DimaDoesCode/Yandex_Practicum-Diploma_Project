# %% [markdown]
# # Телекоммуникации. Прогноз оттока клиентов.

# %% [markdown]
# <div align="center"><font size="4"><b>Дипломный проект.</b></font><br>

# %% [markdown]
# <div align="right"><font size="4">Dmitry K (DimaDoesCode), DS67.</font><br>
# <font size="3">October 30th, 2023.</font></div>

# %% [markdown]
# <h1>Содержание.<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Постановка-задачи." data-toc-modified-id="Постановка-задачи.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Постановка задачи.</a></span></li><li><span><a href="#Настройка-проекта." data-toc-modified-id="Настройка-проекта.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Настройка проекта.</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек,-модулей,-классов-и-функций." data-toc-modified-id="Импорт-библиотек,-модулей,-классов-и-функций.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Импорт библиотек, модулей, классов и функций.</a></span></li><li><span><a href="#Настройка-окружения-и-глобальные-переменные." data-toc-modified-id="Настройка-окружения-и-глобальные-переменные.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Настройка окружения и глобальные переменные.</a></span></li><li><span><a href="#Пользовательские-функции." data-toc-modified-id="Пользовательские-функции.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Пользовательские функции.</a></span><ul class="toc-item"><li><span><a href="#ROC-Анализ-и-Precision-Recall-Анализ." data-toc-modified-id="ROC-Анализ-и-Precision-Recall-Анализ.-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>ROC Анализ и Precision-Recall Анализ.</a></span></li><li><span><a href="#Обзор-DataFrame." data-toc-modified-id="Обзор-DataFrame.-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Обзор DataFrame.</a></span></li><li><span><a href="#Confusion-Matrix." data-toc-modified-id="Confusion-Matrix.-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Confusion Matrix.</a></span></li><li><span><a href="#Отрисовка-Pie-Plot." data-toc-modified-id="Отрисовка-Pie-Plot.-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Отрисовка Pie Plot.</a></span></li><li><span><a href="#Посторение-гистограмм." data-toc-modified-id="Посторение-гистограмм.-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Посторение гистограмм.</a></span></li></ul></li></ul></li><li><span><a href="#Загрузка-данных." data-toc-modified-id="Загрузка-данных.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка данных.</a></span><ul class="toc-item"><li><span><a href="#Dataframe-contract_new." data-toc-modified-id="Dataframe-contract_new.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Dataframe <code>contract_new</code>.</a></span></li><li><span><a href="#Dataframe-internet_new." data-toc-modified-id="Dataframe-internet_new.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Dataframe <code>internet_new</code>.</a></span></li><li><span><a href="#Dataframe-personal_new." data-toc-modified-id="Dataframe-personal_new.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Dataframe <code>personal_new</code>.</a></span></li><li><span><a href="#Dataframe-phone_new." data-toc-modified-id="Dataframe-phone_new.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Dataframe <code>phone_new</code>.</a></span></li><li><span><a href="#Краткий-вывод." data-toc-modified-id="Краткий-вывод.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Краткий вывод.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-и-предобработка-данных." data-toc-modified-id="Исследовательский-анализ-и-предобработка-данных.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ и предобработка данных.</a></span><ul class="toc-item"><li><span><a href="#Преобразование-типа-TotalCharges-и-заполнение-пропусков." data-toc-modified-id="Преобразование-типа-TotalCharges-и-заполнение-пропусков.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Преобразование типа <code>TotalCharges</code> и заполнение пропусков.</a></span></li><li><span><a href="#Преобразование-типа-BeginDate-и-SeniorCitizen." data-toc-modified-id="Преобразование-типа-BeginDate-и-SeniorCitizen.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Преобразование типа <code>BeginDate</code> и <code>SeniorCitizen</code>.</a></span></li><li><span><a href="#Создание-синтетических-признаков-в-DataFrame-contract_new." data-toc-modified-id="Создание-синтетических-признаков-в-DataFrame-contract_new.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Создание синтетических признаков в DataFrame <code>contract_new</code>.</a></span></li><li><span><a href="#Удаление-абсолютных-признаков." data-toc-modified-id="Удаление-абсолютных-признаков.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Удаление абсолютных признаков.</a></span></li><li><span><a href="#Краткий-вывод." data-toc-modified-id="Краткий-вывод.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Краткий вывод.</a></span></li></ul></li><li><span><a href="#Объединение-данных." data-toc-modified-id="Объединение-данных.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Объединение данных.</a></span><ul class="toc-item"><li><span><a href="#Подход-к-объединению-данных." data-toc-modified-id="Подход-к-объединению-данных.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Подход к объединению данных.</a></span></li><li><span><a href="#Объединение-данных." data-toc-modified-id="Объединение-данных.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Объединение данных.</a></span></li><li><span><a href="#Краткий-вывод." data-toc-modified-id="Краткий-вывод.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Краткий вывод.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-и-предобработка-данных-объединённого-датафрейма." data-toc-modified-id="Исследовательский-анализ-и-предобработка-данных-объединённого-датафрейма.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ и предобработка данных объединённого датафрейма.</a></span><ul class="toc-item"><li><span><a href="#Заполнение-пропусков." data-toc-modified-id="Заполнение-пропусков.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Заполнение пропусков.</a></span></li><li><span><a href="#Phi_K-Correlation." data-toc-modified-id="Phi_K-Correlation.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Phi_K Correlation.</a></span></li><li><span><a href="#Диаграммы-данных." data-toc-modified-id="Диаграммы-данных.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Диаграммы данных.</a></span><ul class="toc-item"><li><span><a href="#Partner." data-toc-modified-id="Partner.-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Partner.</a></span></li><li><span><a href="#PaymentMethod." data-toc-modified-id="PaymentMethod.-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>PaymentMethod.</a></span></li><li><span><a href="#MultipleLines." data-toc-modified-id="MultipleLines.-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>MultipleLines.</a></span></li><li><span><a href="#SeniorCitizen." data-toc-modified-id="SeniorCitizen.-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>SeniorCitizen.</a></span></li></ul></li><li><span><a href="#Баланс-класса-и-распределение-числовых-признаков." data-toc-modified-id="Баланс-класса-и-распределение-числовых-признаков.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Баланс класса и распределение числовых признаков.</a></span></li><li><span><a href="#Краткий-вывод." data-toc-modified-id="Краткий-вывод.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Краткий вывод.</a></span></li></ul></li><li><span><a href="#Подготовка-данных." data-toc-modified-id="Подготовка-данных.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Подготовка данных.</a></span></li><li><span><a href="#Обучение-моделей-машинного-обучения." data-toc-modified-id="Обучение-моделей-машинного-обучения.-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Обучение моделей машинного обучения.</a></span><ul class="toc-item"><li><span><a href="#LogisticRegression." data-toc-modified-id="LogisticRegression.-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>LogisticRegression.</a></span></li><li><span><a href="#RandomForestClassifier." data-toc-modified-id="RandomForestClassifier.-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>RandomForestClassifier.</a></span></li><li><span><a href="#CatBoostClassifier." data-toc-modified-id="CatBoostClassifier.-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>CatBoostClassifier.</a></span></li></ul></li><li><span><a href="#Выбор-и-результаты-лучшей-модели." data-toc-modified-id="Выбор-и-результаты-лучшей-модели.-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Выбор и результаты лучшей модели.</a></span><ul class="toc-item"><li><span><a href="#Confusion-Matrix." data-toc-modified-id="Confusion-Matrix.-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Confusion Matrix.</a></span></li><li><span><a href="#ROC-и-Pecision-Recall-кривые." data-toc-modified-id="ROC-и-Pecision-Recall-кривые.-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>ROC и Pecision-Recall кривые.</a></span></li><li><span><a href="#Метод-SHAP." data-toc-modified-id="Метод-SHAP.-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Метод SHAP.</a></span></li></ul></li><li><span><a href="#Общий-вывод-и-рекомендации-заказчику." data-toc-modified-id="Общий-вывод-и-рекомендации-заказчику.-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Общий вывод и рекомендации заказчику.</a></span><ul class="toc-item"><li><span><a href="#Общий-вывод." data-toc-modified-id="Общий-вывод.-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Общий вывод.</a></span></li><li><span><a href="#Рекомендации-заказчику." data-toc-modified-id="Рекомендации-заказчику.-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Рекомендации заказчику.</a></span></li><li><span><a href="#Улучшения-и-перспективы-модели." data-toc-modified-id="Улучшения-и-перспективы-модели.-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Улучшения и перспективы модели.</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Постановка задачи.
#
# <img src="https://s3.amazonaws.com/thumbnails.illustrationsource.com/huge.10.53936.JPG" width="310" align="right"/> **Оператор связи «ТелеДом»** хочет бороться с оттоком клиентов. Для этого его сотрудники начнут предлагать промокоды и специальные условия всем, кто планирует отказаться от услуг связи. Чтобы заранее находить таких пользователей, «ТелеДому» нужна модель, которая будет предсказывать, разорвёт ли абонент договор. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и услугах. Ваша задача — обучить на этих данных модель для прогноза оттока клиентов.
#
# <font size="4"><b>Описание услуг.</b></font>
#
# Оператор предоставляет два основных типа услуг:
#
# - Стационарную телефонную связь. Телефон можно подключить к нескольким линиям одновременно.
# - Интернет. Подключение может быть двух типов: через телефонную линию (`DSL`*,* от англ. digital subscriber line — «цифровая абонентская линия») или оптоволоконный кабель (`Fiber optic`).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (`DeviceProtection`) и блокировка небезопасных сайтов (`OnlineSecurity`);
# - Выделенная линия технической поддержки (`TechSupport`);
# - Облачное хранилище файлов для резервного копирования данных (`OnlineBackup`);
# - Стриминговое телевидение (`StreamingTV`) и каталог фильмов (`StreamingMovies`).
#
# Клиенты могут платить за услуги каждый месяц или заключить договор на 1–2 года. Возможно оплатить счёт разными способами, а также получить электронный чек.
#
# <font size="4"><b>Описание данных.</b></font>
#
# Данные состоят из нескольких файлов, полученных из разных источников:
#
# - `contract_new.csv` — информация о договоре;
# - `personal_new.csv` — персональные данные клиента;
# - `internet_new.csv` — информация об интернет-услугах;
# - `phone_new.csv` — информация об услугах телефонии.
#
# **Файл `contract_new.csv`**
#
# [Скачать файл](https://code.s3.yandex.net/datasets/contract_new.csv)
#
# - `customerID` — идентификатор абонента;
# - `BeginDate` — дата начала действия договора;
# - `EndDate` — дата окончания действия договора;
# - `Type` — тип оплаты: раз в год-два или ежемесячно;
# - `PaperlessBilling` — электронный расчётный лист;
# - `PaymentMethod` — тип платежа;
# - `MonthlyCharges` — расходы за месяц;
# - `TotalCharges` — общие расходы абонента.
#
# **Файл `personal_new.csv`**
#
# [Скачать файл](https://code.s3.yandex.net/datasets/personal_new.csv)
#
# - `customerID` — идентификатор пользователя;
# - `gender` — пол;
# - `SeniorCitizen` — является ли абонент пенсионером;
# - `Partner` — есть ли у абонента супруг или супруга;
# - `Dependents` — есть ли у абонента дети.
#
# **Файл `internet_new.csv`**
#
# [Скачать файл](https://code.s3.yandex.net/datasets/internet_new.csv)
#
# - `customerID` — идентификатор пользователя;
# - `InternetService` — тип подключения;
# - `OnlineSecurity` — блокировка опасных сайтов;
# - `OnlineBackup` — облачное хранилище файлов для резервного копирования данных;
# - `DeviceProtection` — антивирус;
# - `TechSupport` — выделенная линия технической поддержки;
# - `StreamingTV` — стриминговое телевидение;
# - `StreamingMovies` — каталог фильмов.
#
# **Файл `phone_new.csv`**
#
# [Скачать файл](https://code.s3.yandex.net/datasets/phone_new.csv)
#
# - `customerID` — идентификатор пользователя;
# - `MultipleLines` — подключение телефона к нескольким линиям одновременно.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# **Информация о договорах актуальна на 1 февраля 2020 года.**
#
# Данные также находятся в тренажёре, в папке `/datasets/`
#
#
# <font size="4"><b>Метрики качества.</b></font>
#
# Основная метрика для проверки качества модели: `roc_auc`.<br>
# Метрика для интерпретации: `accuracy`

# %% [markdown]
# ## Настройка проекта.

# %% [markdown]
# ### Импорт библиотек, модулей, классов и функций.

# %%
import datetime
import json
import os

try:
    import phik
except ImportError:
    # !pip install phik
    import phik

import random
import warnings

import numpy as np
import pandas as pd
import seaborn as sns

from catboost import CatBoostClassifier, Pool
from IPython.display import Markdown, display
from joblib import dump, load
from matplotlib import pyplot as plt, rcParams, rcParamsDefault
from phik.report import plot_correlation_matrix

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    confusion_matrix,
    precision_recall_curve,
    roc_auc_score,
    roc_curve
)
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, RobustScaler

from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
warnings.simplefilter('ignore', category=NumbaDeprecationWarning)
warnings.simplefilter('ignore', category=NumbaPendingDeprecationWarning)
try:
    import shap
except ImportError:
    # !pip install shap
    import shap

# %% [markdown]
# ### Настройка окружения и глобальные переменные.

# %%
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

ACTUAL_DATE = '2020-02-01'
FACTOR = 10
RANDOM_STATE = 30102023
SHOULD_TRAIN = {
    'LogisticRegression': True,
    'RandomForestClassifier': True,
    'CatBoostClassifier': True
}

default_dpi = rcParamsDefault['figure.dpi']
rcParams['figure.dpi'] = (default_dpi * FACTOR)
rcParams['figure.figsize'] = 8, 4

pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ### Пользовательские функции.

# %% [markdown]
# #### ROC Анализ и Precision-Recall Анализ.

# %%
def my_analyze_classification_performance(model=None, dummy=None, target=None, features=None):
    '''
    Функция предназначена для анализа производительности моделей классификации,
    включая построение ROC-кривой и кривой точности и полноты.
    Она также поддерживает сравнение с dummy моделью, если она предоставлена.
    '''
        
    # Получаем имя модели (закомментированная строка с оригинальной версии кода)
    model_name = 'CatBoostClassifier'  #model.__class__.__name

    # Вычисляем вероятности прогнозов целевой переменной
    target_train_pred_prob = model.predict_proba(features)[:, 1]
    
    # Вычисляем ROC-кривую и AUC-ROC
    fpr, tpr, thresholds = roc_curve(target, target_train_pred_prob)
    auc_roc = roc_auc_score(target, target_train_pred_prob)

    # Если есть dummy модель, то вычисляем ее вероятности и метрики ROC и AUC
    if dummy is not None:
        target_train_pred_prob_dummy = dummy.predict_proba(features)[:, 1]
        fpr_dummy, tpr_dummy, thresholds_dummy = roc_curve(target, target_train_pred_prob_dummy)
        auc_roc_dummy = roc_auc_score(target, target_train_pred_prob_dummy)

    # Создаем график с двумя подграфиками
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
    fig.suptitle(f'Производительность модели классификации {model_name}')

    # График ROC-кривой
    ax[0].plot(fpr, tpr, color='SteelBlue', label='ROC Curve')
    if dummy is not None:
        ax[0].plot(fpr_dummy, tpr_dummy, '--', color='DarkRed', label=('Dummy ' + dummy.strategy))
    else:
        ax[0].plot([0, 1], [0, 1], '--', color='DarkRed', label='Random Guess')
    ax[0].legend(loc='lower right')
    if dummy is not None:
        ax[0].set_title(f'ROC curve (AUC = {auc_roc:.3f})\nDummy {dummy.strategy} AUC = {auc_roc_dummy:.3f}')
    else:
        ax[0].set_title(f'ROC curve (AUC = {auc_roc:.3f})')
    ax[0].set_xlabel('False Positive Rate')
    ax[0].set_ylabel('True Positive Rate')
    ax[0].grid(True)

    # График кривой точности и полноты
    precision, recall, thresholds = precision_recall_curve(target, target_train_pred_prob)
    auc_pr = average_precision_score(target, target_train_pred_prob)

    # Если есть dummy модель, то вычисляем ее кривую точности и полноты, а также AUC
    if dummy is not None:
        precision_dummy, recall_dummy, thresholds_dummy = precision_recall_curve(target, target_train_pred_prob_dummy)
        auc_pr_dummy = average_precision_score(target, target_train_pred_prob_dummy)

    ax[1].plot(recall, precision, color='SteelBlue', label='Precision-Recall Curve')
    if dummy is not None:
        ax[1].plot(recall_dummy, precision_dummy, '--', color='DarkRed', label=('Dummy ' + dummy.strategy))
    else:
        ax[1].plot([0, 1], [1, 0], '--', color='DarkRed', label='Random Guess')
    ax[1].legend(loc='lower left')
    if dummy is not None:
        ax[1].set_title(f'Precision-Recall curve (AUC = {auc_pr:.3f})\nDummy {dummy.strategy} AUC = {auc_pr_dummy:.3f}')
    else:
        ax[1].set_title(f'Precision-Recall curve (AUC = {auc_pr:.3f})')
    ax[1].set_xlabel('Recall')
    ax[1].set_ylabel('Precision')
    ax[1].grid(True)

    # Отображаем графики
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Обзор DataFrame.

# %%
def my_datafame_info(dataframe=None):
    '''
    Функция предназначена для анализа данных в DataFrame,
    включая информацию, полученную с помощью методов info, describe и sample.
    Она отображает эту информацию с использованием заголовков для лучшей читаемости.
    '''
        
    def display_info(title, content):
        # Функция для отображения информации с заголовком
        display(Markdown(f'**{title}**'))
        if content is not None:
            display(content)

    # Получаем статистическую информацию о данных с помощью метода describe
    describe = dataframe.describe(include='all')
    
    # Получаем случайные 10 строк из данных
    sample = dataframe.sample(10, random_state=RANDOM_STATE)

    # Отображаем информацию о данных, полученную с помощью метода info
    display_info('<br>Данные метода info():', None)
    dataframe.info()
    
    # Отображаем статистическую информацию, полученную с помощью метода describe
    display_info("<br>Данные метода describe(include='all'):", describe)
    
    # Отображаем случайные 10 строк данных
    display_info('<br>Данные метода sample(10, random_state=RANDOM_STATE):', sample)

# %% [markdown]
# #### Confusion Matrix.

# %%
def my_confusion_matrix(model=None, target=None, predictions=None):
    '''
    Функция используется для построения матрицы ошибок (Confusion Matrix) для модели классификации.
    Она отображает количество верных и неверных предсказаний модели и
    позволяет визуально оценить производительность модели.
    '''
    
    # Получаем имя модели (закомментированная строка с оригинальной версии кода)
    model_name = 'CatBoostClassifier'  #model.__class__.__name

    # Устанавливаем цветовую схему (cmap)
    cmap = 'Blues'

    # Создаем фигуру и оси для построения матрицы ошибок
    fig, ax = plt.subplots(figsize=(4, 3))

    # Устанавливаем заголовок для графика
    fig.suptitle(f'Confusion matrix для {model_name}')

    # Строим тепловую карту (heatmap) для матрицы ошибок с помощью библиотеки seaborn
    sns.heatmap(confusion_matrix(target, predictions, normalize='all'), 
                cmap=cmap, 
                annot=True, 
                fmt='.2f', 
                ax=ax, 
                vmin=None, 
                vmax=None)

    # Устанавливаем подписи для осей X и Y
    plt.xlabel('Predicted')  # Предсказанные значения
    plt.ylabel('True')       # Реальные значения
    plt.tight_layout()  # Улучшает компоновку графика
    plt.show()  # Отображаем график

# %% [markdown]
# #### Отрисовка Pie Plot.

# %%
def my_plot_pie_charts(data, category_column, target_column, title_column=None):
    '''
    Функция создает и отображает круговые диаграммы для анализа
    процентного распределения целевой переменной в зависимости от категорий.
    '''
        
    # Получаем уникальные категории из столбца
    categories = data[category_column].unique()
    
    # Определяем количество категорий и создаем фигуру с соответствующим числом подграфиков
    num_categories = len(categories)
    fig, axes = plt.subplots(1, num_categories, figsize=(2.5*num_categories, 6))

    # Итерируемся по категориям и строим круговые диаграммы
    for i, category in enumerate(categories):
        # Фильтруем данные для текущей категории
        filtered_data = data[data[category_column] == category]

        # Вычисляем процентное распределение целевой переменной
        percentage_data = (filtered_data.groupby([target_column]).size() / len(filtered_data) * 100).reset_index(name='Percentage')
        
        # Задаем цвета для секторов диаграммы
        colors = ['SteelBlue', 'LightBlue']
        
        # Выбираем текущий подграфик
        ax = axes[i] if num_categories > 1 else axes
        
        # Строим круговую диаграмму
        ax.pie(
            percentage_data['Percentage'],
            labels=None,
            autopct='%1.1f%%',
            startangle=90,
            counterclock=False,
            explode=(0, 0.05),
            colors=colors
        )
        
        # Устанавливаем заголовок для подграфика
        if title_column is not None:
            if title_column is not 'PaymentMethod':
                ax.set_title(f'{title_column}: {category}')
            else:
                ax.set_title(f'{category}')
        
        # Добавляем легенду
        ax.legend(percentage_data[target_column], title=target_column, loc='right')

    # Улучшаем компоновку графиков
    plt.tight_layout()
    
    # Отображаем графики
    plt.show()

# %% [markdown]
# #### Посторение гистограмм.

# %%
def my_plot_histogram_by_feature(data, feature, target_feature):
    '''
    Функция строит гистограмму для выбранного признака feature,
    разделяя данные по значениям target_feature и отображая их на одном графике с легендой. 
    '''
    
    # Два подмножества данных на основе значения третьего признака (0 или 1).
    data_type_0 = data[data[target_feature] == 0]
    data_type_1 = data[data[target_feature] == 1]

    # Гистограмма для каждого значения ThirdFeature на одном графике
    plt.hist(data_type_0[feature], bins='auto', alpha=0.5, label=f'{target_feature} = 0')
    plt.hist(data_type_1[feature], bins='auto', alpha=0.5, label=f'{target_feature} = 1')

    # Подписи для осей, заголовок и легенда
    plt.xlabel(feature)
    plt.ylabel('Частота')
    plt.title(f'Гистограмма для {feature} в зависимости от {target_feature}')
    plt.legend()

    # Отображение
    plt.show()

# %% [markdown]
# ## Загрузка данных.

# %%
file_urls = {
    'contract_new': 'https://code.s3.yandex.net/datasets/contract_new.csv',
    'internet_new': 'https://code.s3.yandex.net/datasets/internet_new.csv',
    'personal_new': 'https://code.s3.yandex.net/datasets/personal_new.csv',
    'phone_new': 'https://code.s3.yandex.net/datasets/phone_new.csv'
}

dataframes = {}

for file_name, file_url in file_urls.items():
    try:
        dataframes[file_name] = pd.read_csv(f'{file_name}.csv')
    except:
        dataframes[file_name] = pd.read_csv(file_url)

# %% [markdown]
# ### Dataframe `contract_new`.

# %%
my_datafame_info(dataframes['contract_new'])
# Out:
# **<br>Данные метода info():**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# **<br>Данные метода describe(include='all'):**
#         customerID   BeginDate EndDate            Type PaperlessBilling  \
# count         7043        7043    7043            7043             7043
# unique        7043          77      67               3                2
# ...

# %% [markdown]
# ### Dataframe `internet_new`.

# %%
my_datafame_info(dataframes['internet_new'])
# Out:
# **<br>Данные метода info():**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB
# **<br>Данные метода describe(include='all'):**
#         customerID InternetService OnlineSecurity OnlineBackup  \
# count         5517            5517           5517         5517
# unique        5517               2              2            2
# top     7590-VHVEG     Fiber optic             No           No
# ...

# %% [markdown]
# ### Dataframe `personal_new`.

# %%
my_datafame_info(dataframes['personal_new'])
# Out:
# **<br>Данные метода info():**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# **<br>Данные метода describe(include='all'):**
#         customerID gender  SeniorCitizen Partner Dependents
# count         7043   7043       7,043.00    7043       7043
# unique        7043      2            NaN       2          2
# top     7590-VHVEG   Male            NaN      No         No
# freq             1   3555            NaN    3641       4933
# mean           NaN    NaN           0.16     NaN        NaN
# std            NaN    NaN           0.37     NaN        NaN
# ...

# %% [markdown]
# ### Dataframe `phone_new`.

# %%
my_datafame_info(dataframes['phone_new'])
# Out:
# **<br>Данные метода info():**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# **<br>Данные метода describe(include='all'):**
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390
# **<br>Данные метода sample(10, random_state=RANDOM_STATE):**
#       customerID MultipleLines
# 505   7343-EOBEU           Yes
# 3385  7010-ZMVBF            No
# 3501  0004-TLHLJ            No
# 6240  5820-PTRYM           Yes
# 2469  1942-OQFRW            No
# 2994  1336-EZFZY            No
# 262   6556-DBKZF            No
# 3372  2103-ZRXFN           Yes
# 5411  9782-LGXMC            No
# ...

# %% [markdown]
# ### Краткий вывод.

# %% [markdown]
# **Этап: Загрузка данных**
#
# 1. Загрузка данных автоматически осуществляется из одного из двух источников: либо из локальных накопителей, либо из удаленного сервера компании Яндекс.
#
# **Этап: Анализ данных**
#
# 1. Dataframe "contract_new":
#     - Результат метода `info()` демонстрирует отсутствие пропусков в данных.
#     - Признаки `BeginDate`, `EndDate`, `SeniorCitizen` и `TotalCharges` требуют приведения к соответствующему формату.
#     - Результат метода `describe(include='all')` подтверждает уникальность каждого значения `customerID` и отсутствие дубликатов по этому признаку.
#     - Визуальный осмотр данных с использованием метода `sample(10, random_state=RANDOM_STATE)` указывает на согласованность данных.
#
# 2. Dataframe "internet_new":
#     - Результат метода `info()` демонстрирует отсутствие пропусков в данных.
#     - Результат метода `describe(include='all')` подтверждает уникальность каждого значения `customerID` и отсутствие дубликатов по этому признаку.
#     - Визуальный осмотр данных с использованием метода `sample(10, random_state=RANDOM_STATE)` также показывает согласованность данных.
#
# 3. Dataframe "personal_new":
#     - Результат метода `info()` демонстрирует отсутствие пропусков в данных.
#     - Результат метода `describe(include='all')` подтверждает уникальность каждого значения `customerID` и отсутствие дубликатов по этому признаку.
#     - Визуальный осмотр данных с использованием метода `sample(10, random_state=RANDOM_STATE)` также подтверждает консистентность данных.
#
# 4. Dataframe "phone_new":
#     - Результат метода `info()` также указывает на отсутствие пропусков в данных.
#     - Результат метода `describe(include='all')` подтверждает уникальность каждого значения `customerID` и отсутствие дубликатов по этому признаку.
#     - Визуальный осмотр данных с использованием метода `sample(10, random_state=RANDOM_STATE)` подтверждает согласованность данных.

# %% [markdown]
# ## Исследовательский анализ и предобработка данных.

# %% [markdown]
# ### Преобразование типа `TotalCharges` и заполнение пропусков.

# %%
dataframes['contract_new']['TotalCharges'] = pd.to_numeric(dataframes['contract_new']['TotalCharges'], errors='coerce')

# %% [markdown]
# Посмотрим на возможно возникшие пропуски в данных после применения обработки ошибок способом `errors='coerce'`.

# %%
dataframes['contract_new'][dataframes['contract_new']['TotalCharges'].isna()]
# Out:
#       customerID   BeginDate EndDate      Type PaperlessBilling  \
# 488   4472-LVYGI  2020-02-01      No  Two year              Yes
# 753   3115-CZMZD  2020-02-01      No  Two year               No
# 936   5709-LVOEQ  2020-02-01      No  Two year               No
# 1082  4367-NUYAO  2020-02-01      No  Two year               No
# 1340  1371-DWPAZ  2020-02-01      No  Two year               No
# 3331  7644-OMVMY  2020-02-01      No  Two year               No
# 3826  3213-VVOLG  2020-02-01      No  Two year               No
# 4380  2520-SGTTA  2020-02-01      No  Two year               No
# 5218  2923-ARZLG  2020-02-01      No  One year              Yes
# 6670  4075-WKNIU  2020-02-01      No  Two year               No
# 6754  2775-SEFEE  2020-02-01      No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges
# 488   Bank transfer (automatic)           52.55           NaN
# 753                Mailed check           20.25           NaN
# ...

# %%
print(f'Дата среза данных: {ACTUAL_DATE}')
# Out:
# Дата среза данных: 2020-02-01

# %% [markdown]
# Все пропуски относятся к договорам заключенным на дату среза данных. Можно предположить, что суммы месячных платежей ещё не успели поступить в раздел общей суммы платежей, счета ещё не были выставлены, либо были ещё не оплачены вовсе. Не будет большим противоречием заполнить пропуски в `TotalCharges` нулями с учетом того, консистентонсть данных предполагает хорошее ведение учёта в компании.

# %%
dataframes['contract_new']['TotalCharges'].fillna(0., inplace=True)

# %% [markdown]
# ### Преобразование типа `BeginDate` и `SeniorCitizen`.

# %%
dataframes['contract_new']['BeginDate'] = pd.to_datetime(dataframes['contract_new']['BeginDate'])
dataframes['personal_new']['SeniorCitizen'] = dataframes['personal_new']['SeniorCitizen'].replace({0: 'No', 1: 'Yes'})

# %% [markdown]
# ### Создание синтетических признаков в DataFrame `contract_new`.

# %%
dataframes['contract_new']['Exited'] = dataframes['contract_new']['EndDate'].apply(lambda x: 0 if x == 'No' else 1)

dataframes['contract_new'].loc[dataframes['contract_new']['EndDate'] == 'No', 'EndDate'] = ACTUAL_DATE 

dataframes['contract_new']['EndDate'] = (
    pd.to_datetime(dataframes['contract_new']['EndDate'])
)
dataframes['contract_new']['ContractDuration'] = (
    (dataframes['contract_new']['EndDate'] - dataframes['contract_new']['BeginDate']).dt.days
)

# %% [markdown]
# ### Удаление абсолютных признаков.

# %%
dataframes['contract_new'].drop(['BeginDate', 'EndDate'], axis=1, inplace=True)

# %%
my_datafame_info(dataframes['contract_new'])
# Out:
# **<br>Данные метода info():**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Type              7043 non-null   object
#  2   PaperlessBilling  7043 non-null   object
#  3   PaymentMethod     7043 non-null   object
#  4   MonthlyCharges    7043 non-null   float64
#  5   TotalCharges      7043 non-null   float64
#  6   Exited            7043 non-null   int64
#  7   ContractDuration  7043 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 440.3+ KB
# **<br>Данные метода describe(include='all'):**
#         customerID            Type PaperlessBilling     PaymentMethod  \
# count         7043            7043             7043              7043
# unique        7043               3                2                 4
# ...

# %% [markdown]
# ### Краткий вывод.

# %% [markdown]
# **Этап: Исследовательский анализ и предобработка данных**
#
# 1. Более детальный анализ признака `TotalCharges` выявил наличие символа "пробел" в некоторых строках признака для контрактов, заключенных в феврале 2020 года. Для приведения признака к числовому формату была использована опция `errors='coerce'`, и возникшие пропуски были заменены на нули. Это замена обоснована, так как для этих новых контрактов счета еще не были выставлены.
#
# 2. Признак `BeginDate` был приведен к типу данных `datetime`. Признак `EndDate` также был приведен к типу данных `datetime` после замены значений `No` на дату выгрузки данных и создания нового признака прекращения контракта `Exited`. Кроме того, был создан новый признак `ContractDuration` для отражения продолжительности действия контракта.
#
# 3. По завершению формирования новых относительных признаков, старые абсолютные признаки `BeginDate` и `EndDate` были удалены из датафрейма.

# %% [markdown]
# ## Объединение данных.

# %% [markdown]
# ### Подход к объединению данных.

# %% [markdown]
# Учитывая результаты предварительного анализа составных датафреймов, их размер и уникальные идентификаторы семплов, разумным подходом к объединению данных предполагается следующая последовательность (слева направо): <i>'contract_new' <- 'personal_new' <- 'phone_new' <- 'internet_new'</i>. Основной идентификатор для объединения данных будет признак `customerID`.

# %% [markdown]
# ### Объединение данных.

# %%
teledom = dataframes['contract_new'].merge(dataframes['personal_new'], on='customerID', how='left')
teledom = teledom.merge(dataframes['phone_new'], on='customerID', how='left')
teledom = teledom.merge(dataframes['internet_new'], on='customerID', how='left')

# %%
del dataframes
my_datafame_info(teledom)
# Out:
# **<br>Данные метода info():**
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Type              7043 non-null   object
#  2   PaperlessBilling  7043 non-null   object
#  3   PaymentMethod     7043 non-null   object
#  4   MonthlyCharges    7043 non-null   float64
#  5   TotalCharges      7043 non-null   float64
#  6   Exited            7043 non-null   int64
#  7   ContractDuration  7043 non-null   int64
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   object
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  MultipleLines     6361 non-null   object
#  13  InternetService   5517 non-null   object
#  14  OnlineSecurity    5517 non-null   object
# ...

# %% [markdown]
# ### Краткий вывод.

# %% [markdown]
# Данные успешно объединены в соответствии с выбранным методом. Однако, визуальный осмотр данных показывает наличие пропусков, которые требуют дополнительной обработки и заполнения.

# %% [markdown]
# ## Исследовательский анализ и предобработка данных объединённого датафрейма.

# %% [markdown]
# ### Заполнение пропусков.

# %% [markdown]
# Учитывая нецелесообразность удаления клиентов с "пропусками", принято решение о разумном заполнении их нейтральной категорией `other`.

# %%
teledom.drop('customerID', axis=1, inplace=True)
teledom.fillna('other', inplace=True)
teledom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7043 non-null   object
#  1   PaperlessBilling  7043 non-null   object
#  2   PaymentMethod     7043 non-null   object
#  3   MonthlyCharges    7043 non-null   float64
#  4   TotalCharges      7043 non-null   float64
#  5   Exited            7043 non-null   int64
#  6   ContractDuration  7043 non-null   int64
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   object
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  MultipleLines     7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# ### Phi_K Correlation.

# %%
INTERVAL_COLUMNS = [
    'MonthlyCharges', 'TotalCharges', 'ContractDuration'
]

# %%
phik_overview = teledom.phik_matrix(interval_cols = INTERVAL_COLUMNS)
plot_correlation_matrix(
    phik_overview.values, 
    x_labels=phik_overview.columns, 
    y_labels=phik_overview.index, 
    vmin=0, vmax=1, color_map='Blues', 
    title=r'Correlation $\phi_K$', 
    fontsize_factor=0.9, 
    figsize=(11, 6)
)
plt.tight_layout()

# %% [markdown]
# Обнаружена мультиколлинеарность, по крайней мере, в паре `TotalCharges - MonthlyCharges`. И сильные зависимости в области значений `other`.
# Обнаружена слабая корреляция целевого признака с признаками `Partner`, `ContractDuration`, `TotalCharge`s или `MonthlyCharges` и `PaymentMethod`. Дополнительный анализ этих признаков выходит за рамки данной работы.

# %% [markdown]
# ### Диаграммы данных.

# %% [markdown]
# Для наглядности, посмотрим на некоторые "портреты" уходящего и остающегося клиентов.

# %% [markdown]
# #### Partner.

# %%
my_plot_pie_charts(teledom, 'Partner', 'Exited', 'Partner')

# %% [markdown]
# #### PaymentMethod.

# %%
my_plot_pie_charts(teledom, 'PaymentMethod', 'Exited', 'PaymentMethod')

# %% [markdown]
# #### MultipleLines.

# %%
my_plot_pie_charts(teledom, 'MultipleLines', 'Exited', 'MultipleLines')

# %% [markdown]
# #### SeniorCitizen.

# %%
my_plot_pie_charts(teledom, 'SeniorCitizen', 'Exited', 'SeniorCitizen')

# %% [markdown]
# ### Баланс класса и распределение числовых признаков.

# %%
plt.figure(figsize=(5, 4))
teledom['Exited'].value_counts(normalize=True).plot.bar(color='SteelBlue')
plt.ylabel('Плотность')
plt.title('Плотность распределения целевого признака')
plt.xticks([0, 1], ['Остался', 'Ушёл'], rotation=0)
plt.tight_layout()
plt.show()

# %%
my_plot_histogram_by_feature(teledom, 'TotalCharges', 'Exited')

# %%
my_plot_histogram_by_feature(teledom, 'MonthlyCharges', 'Exited')

# %%
my_plot_histogram_by_feature(teledom, 'ContractDuration', 'Exited')

# %% [markdown]
# ### Краткий вывод.

# %% [markdown]
# **Этап: Исследовательский анализ и предобработка данных объединенного датафрейма**
#
# 1. Заполнение пропусков:
#     - Учитывая нецелесообразность удаления клиентов с "пропусками", принято решение о разумном заполнении их нейтральной категорией `other`.
# 2. Анализ Phi_K коэффициентов:
#     - Обнаружена мультиколлинеарность, по крайней мере, в паре `TotalCharges` - `MonthlyCharges`. И сильные зависимости в области значений `other`.
#
#     - Поскольку сейчас не совсем ясно, какой тип регуляризации (L1 или L2) лучше подходит для модели логистической регрессии, будет произведен подбор параметра C, который позволяет настраивать степень общей регуляризации без явного учета её типа.
#     - Обнаружена слабая корреляция целевого признака с признаками `Partner`, `ContractDuration`, `TotalCharges` или `MonthlyCharges` и `PaymentMethod`. Дополнительный анализ этих признаков выходит за рамки данной работы.
#
# 3. Целевой признак объединенного датафрейма имеет явный дисбаланс класса, в то время как числовые признаки датафрейма обладают разумными распределениями без явных аномалий и выбросов.

# %% [markdown]
# ## Подготовка данных.

# %%
features = teledom.drop(['Exited'], axis=1)
labels = teledom['Exited']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features,
    labels,
    test_size=0.25, 
    stratify=labels,
    random_state=RANDOM_STATE
)

# %%
dataframes_to_reset = [X_train, X_test, y_train, y_test]

for df in dataframes_to_reset:
    df.reset_index(drop=True, inplace=True)

# %%
print(f'Баланс класса обучающей выборки: {y_train.mean():.2%}')
# Out:
# Баланс класса обучающей выборки: 15.64%

# %%
print(f'Баланс класса тестовой выборки: {y_test.mean():.2%}')
# Out:
# Баланс класса тестовой выборки: 15.62%

# %% [markdown]
# **Этап: Подготовка данных**
#
# 1. Разделение на признаки и метки:
#    - Объединенный датафрейм был разделен на признаки и метки.<br><br>
#
# 2. Разделение на обучающие и тестовые выборки:
#    - С использованием функции `train_test_split`, данные признаков и меток были стратифицированно и перемешанно разделены на тестовые и обучающие выборки в соответствии с техническим заданием в пропорции 3:1.<br><br>
#
# 3. Индексы новых датафреймов:
#    - Для удобства были пересозданы индексы новых датафреймов.
#    - Проверка баланса класса показала хорошую стратификацию выборок.

# %% [markdown]
# ## Обучение моделей машинного обучения.

# %%
NUM = ['MonthlyCharges', 'TotalCharges', 'ContractDuration']
CAT = list(X_train.select_dtypes(include=['object']))

# %% [markdown]
# ### LogisticRegression.

# %%
logistic_preprocessing = ColumnTransformer([
    ('num', Pipeline([
        #('scale', StandardScaler())
        ('scale', RobustScaler())
    ]), NUM), 
    ('cat', Pipeline([
        ('onehot', OneHotEncoder(sparse=False, drop='first')),
        #('scale', StandardScaler())
    ]), CAT)
], remainder='drop')

# %%
logistic_pipeline = Pipeline([
    ('preprocessing', logistic_preprocessing),
    ('lr', LogisticRegression(random_state=RANDOM_STATE))
])

# %%
logistic_pipeline
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scale',
#                                                                    RobustScaler())]),
#                                                   ['MonthlyCharges',
#                                                    'TotalCharges',
#                                                    'ContractDuration']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   ['Type', 'PaperlessBilling',
#                                                    'PaymentMethod', 'gender',
# ...

# %% [markdown]
#  Для ускорения проверки будем использовать сокращенный набор гиперпараметров на основании ранее проведённых исследований модели.

# %%
if os.path.exists('gridsearch_lr_results.joblib') and not SHOULD_TRAIN['LogisticRegression']:
    grid_search_lr = load('gridsearch_lr_results.joblib')
    print('Результаты GridSearchCV для LogisticRegression загружены из файла')
else:
    param_grid = {
        'lr__C': [10, 100, 1000, 10000],
        'lr__class_weight': ['balanced', None]
    }

    grid_search_lr = GridSearchCV(
        logistic_pipeline,
        param_grid = param_grid,
        scoring='roc_auc',
        n_jobs=-1,
        verbose=0
    )
    grid_search_lr.fit(X_train, y_train)
    
    dump(grid_search_lr, 'gridsearch_lr_results.joblib')
    print('Результаты GridSearchCV для LogisticRegression сохранены в файле')
# Out:
# Результаты GridSearchCV для LogisticRegression сохранены в файле

# %%
print(
    f'Лучшие гиперпараметры для модели LogisticRegression:\n\
{json.dumps(grid_search_lr.best_params_, indent=4, sort_keys=True)}'
)
# Out:
# Лучшие гиперпараметры для модели LogisticRegression:
# {
#     "lr__C": 100,
#     "lr__class_weight": null
# }

# %%
print(
    f'Кроссвалидационная ROC AUC для модели LogisticRegression: {grid_search_lr.best_score_:.2f}'
)
# Out:
# Кроссвалидационная ROC AUC для модели LogisticRegression: 0.76

# %% [markdown]
# **Этап: Модель LogisticRegression**
#
# 1. Создание пайплайна для LogisticRegression:
#    - Создан пайплайн для модели логистической регрессии, включающий в себя `ColumnTransformer` для предобработки данных и саму модель логистической регрессии. В этом пайплайне использованы `StandardScaler` и `OneHotEncoder`, соответствуя выбранной модели.<br><br>
#
# 2. Результаты модели LogisticRegression:
#    - Несмотря на быстрое обучение и успешное прохождение кросс-валидации на `GridSearchCV`, модель логистической регрессии не продемонстрировала удовлетворительных результатов. Кросс-валидационное значение ROC AUC для модели `LogisticRegression` составило $0.76$.

# %% [markdown]
# ### RandomForestClassifier.

# %%
rfc_preprocessing = ColumnTransformer([
    ('cat', Pipeline([
        ('ordinal', OrdinalEncoder()),
    ]), CAT)
], remainder='passthrough')

# %%
rfc_pipeline = Pipeline([
    ('preprocessing', rfc_preprocessing),
    ('rfc', RandomForestClassifier(random_state=RANDOM_STATE))
])

# %%
rfc_pipeline
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('ordinal',
#                                                                    OrdinalEncoder())]),
#                                                   ['Type', 'PaperlessBilling',
#                                                    'PaymentMethod', 'gender',
#                                                    'SeniorCitizen', 'Partner',
#                                                    'Dependents',
#                                                    'MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
# ...

# %% [markdown]
#  Для ускорения проверки будем использовать сокращенный набор гиперпараметров на основании ранее проведённых исследований модели.

# %%
if os.path.exists('gridsearch_rfc_results.joblib') and not SHOULD_TRAIN['RandomForestClassifier']:
    grid_search_rfc = load('gridsearch_rfc_results.joblib')
    print('Результаты GridSearchCV для RandomForestClassifier загружены из файла')
else:
    param_grid = {
        'rfc__n_estimators': [70, 90, 110],
        'rfc__class_weight': ['balanced', None],
        'rfc__max_depth': [7, 9, 11]
    }

    grid_search_rfc = GridSearchCV(
        rfc_pipeline,
        param_grid = param_grid,
        scoring='roc_auc',
        n_jobs=-1,
        verbose=0
    )
    grid_search_rfc.fit(X_train, y_train)
    
    dump(grid_search_rfc, 'gridsearch_rfc_results.joblib')
    print('Результаты GridSearchCV для RandomForestClassifier сохранены в файле')
# Out:
# Результаты GridSearchCV для RandomForestClassifier сохранены в файле

# %%
print(
    f'Лучшие гиперпараметры для модели RandomForestClassifier:\n\
{json.dumps(grid_search_rfc.best_params_, indent=4, sort_keys=True)}'
)
# Out:
# Лучшие гиперпараметры для модели RandomForestClassifier:
# {
#     "rfc__class_weight": null,
#     "rfc__max_depth": 7,
#     "rfc__n_estimators": 110
# }

# %%
print(f'Кроссвалидационная ROC AUC для модели RandomForestClassifier: {grid_search_rfc.best_score_:.2f}')
# Out:
# Кроссвалидационная ROC AUC для модели RandomForestClassifier: 0.83

# %% [markdown]
# **Этап: Модель RandomForestClassifier**
#
# 1. Создание пайплайна для RandomForestClassifier:
#    - Создан пайплайн для модели `RandomForestClassifier`, включающий в себя `ColumnTransformer` для предобработки данных и саму модель `RandomForestClassifier`. В данном пайплайне использован только `OrdinalEncoder`, соответствуя выбранной модели.<br><br>
#
# 2. Результаты модели RandomForestClassifier:
#    - Обучение и кросс-валидация на `GridSearchCV` для модели `RandomForestClassifier` заняли больше времени. Однако полученные результаты оказались ниже ожидаемых. Кросс-валидационное значение ROC AUC для модели `RandomForestClassifier` составило $0.83$.

# %% [markdown]
# ### CatBoostClassifier.

# %%
train_dataset = Pool(X_train, y_train, cat_features=CAT)

# %% [markdown]
#  Для ускорения проверки будем использовать сокращенный набор гиперпараметров на основании ранее проведённых исследований модели.

# %%
if os.path.exists('gridsearch_cbc_results.joblib') and not SHOULD_TRAIN['CatBoostClassifier']:
    (catboost_model, grid_search_result) = load('gridsearch_cbc_results.joblib')
    print('Результаты grid_search для CatBoostClassifier загружены из файла')
else:
    catboost_model = CatBoostClassifier(
        loss_function='Logloss',
        eval_metric='AUC:hints=skip_train~false',
        logging_level='Silent',
        random_state=RANDOM_STATE
    )

    grid = {
        'iterations': [200, 500],
        'auto_class_weights': ['Balanced', None],
        'learning_rate': [0.03, 0.1],
        'depth': [6, 8],
        'l2_leaf_reg': [0.2, 0.5]
    }

    grid_search_result = catboost_model.grid_search(grid, train_dataset, cv=5, plot=True, verbose=False)
    
    dump((catboost_model, grid_search_result), 'gridsearch_cbc_results.joblib')
    print('Результаты grid_search для CatBoostClassifier сохранены в файле')
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Результаты grid_search для CatBoostClassifier сохранены в файле

# %%
print(
    f'Лучшие гиперпараметры для модели CatBoostClassifier:\n\
{json.dumps(catboost_model.get_params(), indent=4, sort_keys=True)}'
)
# Out:
# Лучшие гиперпараметры для модели CatBoostClassifier:
# {
#     "auto_class_weights": "Balanced",
#     "depth": 6,
#     "eval_metric": "AUC:hints=skip_train~false",
#     "iterations": 500,
#     "l2_leaf_reg": 0.5,
#     "learning_rate": 0.1,
#     "logging_level": "Silent",
#     "loss_function": "Logloss",
#     "random_state": 30102023
# }

# %%
print(f'Кроссвалидационная ROC AUC для модели CatBoostClassifier: \
{json.dumps(catboost_model.get_best_score(), indent=4, sort_keys=True)}')
# Out:
# Кроссвалидационная ROC AUC для модели CatBoostClassifier: {
#     "learn": {
#         "AUC": 0.9994740068074821,
#         "Logloss": 0.10905779204712913
#     }
# }

# %% [markdown]
# **Этап: Модель CatBoostClassifier**
#
# 1. Подход к предобработке данных для CatBoostClassifier:
#    - Для модели CatBoostClassifier нет необходимости создавать сложный пайплайн предобработки данных. Вместо этого достаточно передать список категориальных признаков, и сама модель выполнит предобработку автоматически.<br><br>
#
# 2. Результаты модели CatBoostClassifier:
#    - С учетом подбора гиперпараметров на кросс-валидации, модель показала результат, который может показаться необычным и может свидетельствовать о переобучении. Тем не менее, значение ROC AUC, равное $0.99$, позволяет считать эту модель лучшей, и ее следует протестировать на тестовой выборке.

# %% [markdown]
# ## Выбор и результаты лучшей модели.

# %% [markdown]
# Как было указано ранее, решено провести тестирование ранее обученной модели `CatBoostClassifier` на тестовой выборке.

# %%
test_dataset = Pool(X_test, y_test, cat_features=CAT)

# %%
print(
    f'Тестовая ROC AUC для модели CatBoostClassifier: \
{roc_auc_score(y_test, catboost_model.predict_proba(test_dataset)[:, 1]):.2f}'
)
# Out:
# Тестовая ROC AUC для модели CatBoostClassifier: 0.90

# %%
print(
    f'Тестовая Accuracy для модели CatBoostClassifier: \
{accuracy_score(y_test, catboost_model.predict(X_test)):.2f}'
)
# Out:
# Тестовая Accuracy для модели CatBoostClassifier: 0.89

# %%
pd.Series(
    index=catboost_model.feature_names_,
    data=catboost_model.feature_importances_
).sort_values().plot(kind='barh', color='SteelBlue')

plt.title('CatBoost Feature Importance')
plt.show()

# %% [markdown]
# На этапе тестирования, модель CatBoostClassifier показала следующие результаты:
# - ROC AUC составил $0.90$.
# - Дополнительная метрика Accuracy равняется $0.89$.
# - Наиболее значимыми признаками для модели оказались следующие (в порядке убывания важности): `ContractDuration`, `TotalCharges`, `MonthlyCharges`, `PaymentMethod` и `Type` и т.д.
#
# Следующим шагом будет более детальное рассмотрение характеристик этой модели.

# %% [markdown]
# ### Confusion Matrix.

# %%
my_confusion_matrix(model=catboost_model, target=y_test, predictions=catboost_model.predict(X_test))

# %% [markdown]
# Матрица ошибок даёт более детальную картину значения Accuracy. В данной матрице ошибок:
# - **(TN)** (True Negatives) равно $0.78$,
# - **(TP)** (True Positives) равно $0.11$,
# - **(FN)** (False Negatives) равно $0.05$,
# - **(FP)** (False Positives) равно $0.06$.
#
# Таким образом видно, что значения False Negatives и False Positives примерно одинаковы и модель сбалансированно ошибается в обе стороны в примерно $11\%$ случаев.

# %% [markdown]
# ### ROC и Pecision-Recall кривые.

# %%
param_grid = {'strategy': ['most_frequent']}#, 'prior', 'stratified', 'uniform']}

model_dummy = DummyClassifier(random_state=RANDOM_STATE)

grid_search_dummy = GridSearchCV(model_dummy, param_grid = param_grid, scoring='roc_auc')
grid_search_dummy.fit(X_train, y_train)
print(
    f'Лучший гиперпараметр модели DummyClassifier:\n\
{json.dumps(grid_search_dummy.best_params_, indent=4, sort_keys=True)}'
)
# Out:
# Лучший гиперпараметр модели DummyClassifier:
# {
#     "strategy": "most_frequent"
# }

# %%
dummy = grid_search_dummy.best_estimator_

# %%
my_analyze_classification_performance(model=catboost_model, dummy=dummy, target=y_test, features=X_test)

# %% [markdown]
# Значения ROC AUC (Receiver Operating Characteristic Area Under Curve) и PR AUC (Precision-Recall Area Under Curve):
#
# 1. **ROC AUC (Receiver Operating Characteristic Area Under Curve):** Значение ROC AUC равное $0.904$ говорит о том, что модель хорошо разделяет классы, и эффективно различает их на основе кривой ROC.
#
# 2. **PR AUC (Precision-Recall Area Under Curve):** Значение PR AUC равное $0.759$ указывает на хорошую способность модели выявлять положительные примеры с высокой точностью.

# %% [markdown]
# ### Метод SHAP.

# %%
explainer = shap.TreeExplainer(catboost_model)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test, feature_names=catboost_model.feature_names_, plot_size=(8,6))

# %% [markdown]
# **Интерпретация результатов:**
#
# Результаты интерпретации с использованием SHAP позволяют понять, какие признаки оказывают наибольшее влияние на возможность ухода клиента. С учетом этого, можно сделать следующие выводы:
#
# 1. **Продолжительность действия контракта:** Наибольший вклад в предсказание возможности ухода клиента оказывает продолжительность действия контракта. Это означает, что чем дольше клиент пользуется услугами компании, тем менее вероятно, что он уйдет. Этот признак имеет сильное положительное влияние на удержание клиентов.
#
# 2. **Общие и ежемесячные платежи:** Высокие общие и ежемесячные платежи также существенно влияют на предсказания модели. Они являются важным фактором для оценки вероятности ухода клиента. Более высокие платежи могут увеличить вероятность ухода клиента, поэтому они требуют внимания компании предоставляющей услуги связи.

# %% [markdown]
# ## Общий вывод и рекомендации заказчику.

# %% [markdown]
# ### Общий вывод.

# %% [markdown]
# В ходе анализа данных и исследовательской работы были проведены последовательные этапы анализа, предобработки, обучения моделей и их интерпретации. Основные шаги и результаты этого исследования включают в себя следующее:
#
# 1. **Загрузка данных и предобработка:**
#    - Данные были загружены из разных источников, объединены и предварительно обработаны.
#    - Произведена замена значений, исправление типов данных и удаление ненужных признаков.<br><br>
#
# 2. **Исследовательский анализ данных:**
#    - Был проведен анализ распределения данных и выявление мультиколлинеарности.
#    - Выявлен явный дисбаланс класса в целевом признаке.<br><br>
#
# 3. **Подготовка данных:**
#    - Данные были разделены на признаки и метки.
#    - Выполнено разделение данных на обучающую и тестовую выборки с учетом стратификации.<br><br>
#
# 4. **Модели машинного обучения:**
#    - Проведено обучение и оценка нескольких моделей, включая `LogisticRegression`, `RandomForestClassifier` и `CatBoostClassifier`.
#    - Наиболее высокое значение ROC AUC было достигнуто с использованием `CatBoostClassifier`.<br><br>
#
# 5. **Интерпретация модели:**
#    - Использован метод SHAP для интерпретации модели `CatBoostClassifier`.
#    - Выявлены наиболее важные признаки, влияющие на возможность ухода клиентов.

# %% [markdown]
# ### Рекомендации заказчику.

# %% [markdown]
# Конечный результат данного исследования предоставляет полезную информацию для лучшего понимания факторов, влияющих на удержание клиентов, и способствует разработке стратегий для предотвращения их оттока. Данное исследование предоставляет компании «ТелеДом», оказывающей услуги связи, основные аспекты более глубокого понимания клиентов и принятия мер по их удержанию.
#
# Особое внимание следует уделить интерпретации результатов модели с использованием SHAP, что позволяет выявить потенциально нелояльных клиентов и разработать более точные стратегии удержания.
#
# Так же представляется разумным запросить у заказчика, для улучшения модели, дополнительные обезличенные, но более персонифицированные данные о клиентах и пользовании ими более расширенным спектром услуг.

# %% [markdown]
# ### Улучшения и перспективы модели.

# %% [markdown]
# Существует несколько потенциальных путей для улучшения текущей модели:
#
# 1. **Тюнинг гиперпараметров:** Проведение более глубокого поиска оптимальных гиперпараметров для выбранной модели может значительно повысить её производительность.
#
# 2. **Снижение размерности данных:** Рассмотрение возможности применения методов снижения размерности данных, таких как PCA (Principal Component Analysis), чтобы улучшить производительность модели и сократить время обучения.
#
# 3. **Использование встроенных средств CatBoost:** Исследование возможностей, предоставляемых непосредственно CatBoost, таких как автоматический выбор признаков и оптимизация гиперпараметров.
#
# 4. **Расширенная предобработка данных:** Возможность применения более сложных методов предобработки данных, таких как создание новых признаков, обработка выбросов и учет дополнительных факторов, которые могут влиять на отток.
#
# 5. **Запрос дополнительных данных:** По доступности запросить у заказчика для улучшения модели дополнительных обезличенных, но более персонифицированных данных о клиентах и их пользовании услугами.

# %% [markdown]
# ![image.png](attachment:image.png)
